# %%
pip install openai==0.28
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %env OPENAI_API_KEY=key
# Out:
# env: OPENAI_API_KEY=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

# %%
import os
import openai
import wandb


openai.api_key = os.getenv("OPENAI_API_KEY")

# %%
gpt_prompt = """
You are going to make a dataset that gives us questions and answers of a given dataset. The output should be the information in a json format and the specific information is decribed below:

This is the dataset:
{
  "employees": [
    {
      "name": "John Smith",
      "role": "Software Engineer",
      "years_at_company": 5,
      "skills": {
        "languages": ["Python", "Java", "JavaScript"],
        "technologies": ["AWS", "Linux", "GPT"]
      }
    },
    {
      "name": "Emily Johnson",
      "role": "Marketing Manager",
      "years_at_company": 3,
      "skills": {
        "nontechnical": ["Communication", "Leadership", "Problem-solving"],
        "software": ["Excel", "Agile methodologies", "Notion"]
      }
    },
    {
      "name": "Michael Williams",
      "role": "Data Analyst",
      "years_at_company": 2,
      "skills": {
        "languages": ["SQL", "R", "Python"],
        "technologies": ["Tableau", "Power BI", "Google Analytics"]
      }
    },
    {
      "name": "Sarah Brown",
      "role": "Human Resources Manager",
      "years_at_company": 7,
      "skills": {
        "nontechnical": ["Communication", "Leadership", "Problem-solving"],
        "software": ["Excel", "HRIS", "Performance management"]
      }
    },
    {
      "name": "David Lee",
      "role": "Product Manager",
      "years_at_company": 10,
      "skills": {
        "nontechnical": ["Communication", "Leadership", "Problem-solving"],
        "software": ["Excel", "Agile methodologies", "JIRA"]
      }
    },
    {
      "name": "Jessica Chen",
      "role": "UX Designer",
      "years_at_company": 1,
      "skills": {
        "design": ["UI/UX design", "Wireframing", "Prototyping"],
        "software": ["Adobe XD", "Figma", "Sketch"]
      }
    },
    {
      "name": "Kevin Nguyen",
      "role": "Front-end Developer",
      "years_at_company": 4,
      "skills": {
        "languages": ["HTML", "CSS", "JavaScript"],
        "technologies": ["React", "Angular", "Bootstrap"]
      }
    },
    {
      "name": "Linda Kim",
      "role": "Accountant",
      "years_at_company": 6,
      "skills": {
        "nontechnical": ["Attention to detail", "Analytical skills", "Time management"],
        "software": ["Excel", "QuickBooks", "SAP"]
      }
    },
    {
      "name": "Ryan Garcia",
      "role": "Sales Manager",
      "years_at_company": 8,
      "skills": {
        "nontechnical": ["Communication", "Negotiation", "Customer relationship management"],
        "software": ["Salesforce", "HubSpot", "Pipedrive"]
      }
    },
    {
      "name": "Amanda Patel",
      "role": "Graphic Designer",
      "years_at_company": 2,
      "skills": {
        "design": ["Graphic design", "Typography", "Branding"],
        "software": ["Adobe Photoshop", "Illustrator", "InDesign"]
      }
    },
    {
      "name": "Daniel Hernandez",
      "role": "Back-end Developer",
      "years_at_company": 3,
      "skills": {
        "languages": ["Java", "Python", "C++"],
        "technologies": ["Node.js", "Django", "MySQL"]
      }
    },
    {
      "name": "Rachel Chen",
      "role": "Content Writer",
      "years_at_company": 2,
      "skills": {
        "writing": ["Copywriting", "Blogging", "SEO"],
        "software": ["WordPress", "Google Docs", "Grammarly"]
      }
    },
    {
      "name": "Erica Wong",
      "role": "Project Manager",
      "years_at_company": 9,
      "skills": {
        "nontechnical": ["Communication", "Leadership", "Project management"],
        "software": ["Microsoft Project", "Asana", "Trello"]
      }
    },
    {
      "name": "Matthew Kim",
      "role": "IT Support Specialist",
      "years_at_company": 4,
      "skills": {
        "languages": ["Python", "Java", "C#"],
        "technologies": ["Windows Server", "Active Directory", "VMware"]
      }
    },
    {
      "name": "Julia Rodriguez",
      "role": "Social Media Manager",
      "years_at_company": 2,
      "skills": {
        "nontechnical": ["Social media marketing", "Content creation", "Analytics"],
        "software": ["Hootsuite", "Buffer", "Google Analytics"]
      }
    },
    {
      "name": "Mark Chen",
      "role": "Business Analyst",
      "years_at_company": 5,
      "skills": {
        "nontechnical": ["Analytical skills", "Critical thinking", "Problem-solving"],
        "software": ["Excel", "PowerPoint", "SAP"]
      }
    },
    {
      "name": "Samantha Lee",
      "role": "UI Designer",
      "years_at_company": 3,
      "skills": {
        "design": ["UI design", "User research", "Usability testing"],
        "software": ["Adobe XD", "Sketch", "InVision"]
      }
    },
    {
      "name": "Alex Nguyen",
      "role": "Full-stack Developer",
      "years_at_company": 6,
      "skills": {
        "languages": ["JavaScript", "Python", "PHP"],
        "technologies": ["React", "Node.js", "MySQL"]
      }
    },
    {
      "name": "Grace Kim",
      "role": "Customer Service Representative",
      "years_at_company": 1,
      "skills": {
        "nontechnical": ["Customer service", "Problem-solving", "Time management"],
        "software": ["Zendesk", "Freshdesk", "Salesforce"]
      }
    },
    {
      "name": "Justin Chen",
      "role": "DevOps Engineer",
      "years_at_company": 7,
      "skills": {
        "languages": ["Python", "Bash", "Java"],
        "technologies": ["AWS", "Docker", "Kubernetes"]
      }
    },
    {
      "name": "Natalie Kim",
      "role": "Copywriter",
      "years_at_company": 4,
      "skills": {
        "writing": ["Copywriting", "Content marketing", "SEO"],
        "software": ["Google Docs", "WordPress", "Grammarly"]
      }
    },
    {
      "name": "Brandon Chen",
      "role": "Software Tester",
      "years_at_company": 2,
      "skills": {
        "languages": ["Java", "Python", "C#"],
        "technologies": ["Selenium", "JUnit", "Postman"]
      }
    },
    {
      "name": "Sophia Lee",
      "role": "Digital Marketing Manager",
      "years_at_company": 8,
      "skills": {
        "nontechnical": ["Digital marketing", "Analytics", "Project management"],
        "software": ["Google Ads", "Google Analytics", "Hootsuite"]
      }
    },
    {
      "name": "Ethan Nguyen",
      "role": "Network Engineer",
      "years_at_company": 6,
      "skills": {
        "languages": ["Python", "Java", "C++"],
        "technologies": ["Cisco", "Juniper", "VMware"]
      }
    },
    {
      "name": "Isabella Kim",
      "role": "Event Coordinator",
      "years_at_company": 3,
      "skills": {
        "nontechnical": ["Event planning", "Communication", "Time management"],
        "software": ["Eventbrite", "Cvent", "Asana"]
      }
    },
    {
      "name": "Lucas Chen",
      "role": "Database Administrator",
      "years_at_company": 9,
      "skills": {
        "languages": ["SQL", "Python", "Java"],
        "technologies": ["MySQL", "Oracle", "SQL Server"]
      }
    },
    {
      "name": "Olivia Lee",
      "role": "Content Strategist",
      "years_at_company": 4,
      "skills": {
        "writing": ["Content strategy", "SEO", "Copywriting"],
        "software": ["Google Analytics", "SEMRush", "WordPress"]
      }
    },
    {
      "name": "Dylan Nguyen",
      "role": "UI/UX Designer",
      "years_at_company": 2,
      "skills": {
        "design": ["UI/UX design", "Wireframing", "Prototyping"],
        "software": ["Adobe XD", "Figma", "Sketch"]
      }
    }

Based on the dataset, answer the following questions regarding the data:
What team has a software engineer, designer, and business person?
What team is the best at creating a web app?
What team is the best at creating a phone app?
What team is the best at creating a machine learning algorithm?
What team is the best at handling HR related concerns?
What team is the best for backend deployment?
What team is the best for debugging issues with AWS?
What team is the best for managing interns?
What team is the best for recruiting employees?
What team is the best for presenting a new product?

The output should contain the questions and names of the people in a json format.
"""


response = openai.Completion.create(
  engine="gpt-3.5-turbo-instruct",
  prompt=gpt_prompt,
  temperature=0.5,
  top_p=1.0,
  max_tokens=1000,
  frequency_penalty=0.0,
  presence_penalty=0.0,
)


print(response['choices'][0]['text'])
# Out:
# {
#   "Question 1": "What team has a software engineer, designer, and business person?",
#   "Answer 1": "The team with John Smith as the software engineer, Jessica Chen as the designer, and David Lee as the business person.",
#   "Question 2": "What team is the best at creating a web app?",
#   "Answer 2": "The team with Kevin Nguyen as the front-end developer, Alex Nguyen as the full-stack developer, and Daniel Hernandez as the back-end developer.",
#   "Question 3": "What team is the best at creating a phone app?",
#   "Answer 3": "The team with Jessica Chen as the UX designer, Alex Nguyen as the full-stack developer, and Daniel Hernandez as the back-end developer.",
#   "Question 4": "What team is the best at creating a machine learning algorithm?",
#   "Answer 4": "The team with John Smith as the software engineer, Michael Williams as the data analyst, and Justin Chen as the DevOps engineer.",
#   "Question 5": "What team is the best at handling HR related concerns?",
# ...
